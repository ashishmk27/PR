# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from fcmeans import FCM
from sklearn.datasets import load_wine

# Load publicly available dataset (Wine dataset)
wine = load_wine()
X = wine.data[:, :2]  # Taking only the first two features for visualization

# Standardizing the dataset
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply Fuzzy C-Means
fcm = FCM(n_clusters=3, m=2.0, max_iter=150, error=1e-5, random_state=42)
fcm.fit(X_scaled)

# Get cluster centers and labels
centers = fcm.centers
labels = fcm.predict(X_scaled)

# Plot results
plt.figure(figsize=(8, 6))
for i in range(3):
    plt.scatter(X_scaled[np.where(labels == i), 0], X_scaled[np.where(labels == i), 1], label=f'Cluster {i+1}')
plt.scatter(centers[:, 0], centers[:, 1], marker='x', color='black', s=200, label='Centers')
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.title("Fuzzy C-Means Clustering on Wine Dataset")
plt.show()

# %%
# !pip install fuzzy-c-means
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting fuzzy-c-means
#   Downloading fuzzy_c_means-1.7.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: joblib<2.0.0,>=1.2.0 in c:\users\ashish mahendran\appdata\roaming\python\python312\site-packages (from fuzzy-c-means) (1.4.2)
# Requirement already satisfied: numpy<2.0.0,>=1.21.1 in c:\users\ashish mahendran\appdata\roaming\python\python312\site-packages (from fuzzy-c-means) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.4 in c:\users\ashish mahendran\appdata\roaming\python\python312\site-packages (from fuzzy-c-means) (2.10.5)
# Collecting tabulate<0.9.0,>=0.8.9 (from fuzzy-c-means)
#   Downloading tabulate-0.8.10-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.1 in c:\users\ashish mahendran\appdata\roaming\python\python312\site-packages (from fuzzy-c-means) (4.66.5)
# Collecting typer<0.10.0,>=0.9.0 (from fuzzy-c-means)
#   Downloading typer-0.9.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ashish mahendran\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.6.4->fuzzy-c-means) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\ashish mahendran\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.6.4->fuzzy-c-means) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\ashish mahendran\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.6.4->fuzzy-c-means) (4.12.2)
# Requirement already satisfied: colorama in c:\users\ashish mahendran\appdata\roaming\python\python312\site-packages (from tqdm<5.0.0,>=4.64.1->fuzzy-c-means) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\ashish mahendran\appdata\roaming\python\python312\site-packages (from typer<0.10.0,>=0.9.0->fuzzy-c-means) (8.1.7)
# Downloading fuzzy_c_means-1.7.2-py3-none-any.whl (9.1 kB)
# Downloading tabulate-0.8.10-py3-none-any.whl (29 kB)
# Downloading typer-0.9.4-py3-none-any.whl (45 kB)
# Installing collected packages: tabulate, typer, fuzzy-c-means
#   Attempting uninstall: typer
#     Found existing installation: typer 0.15.2
#     Uninstalling typer-0.15.2:
#       Successfully uninstalled typer-0.15.2
# Successfully installed fuzzy-c-means-1.7.2 tabulate-0.8.10 typer-0.9.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 5.23.2 requires typer<1.0,>=0.12; sys_platform != "emscripten", but you have typer 0.9.4 which is incompatible.
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
